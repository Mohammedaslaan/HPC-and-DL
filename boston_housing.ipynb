# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammedaslaan/HPC-and-DL/blob/main/boston_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/content/1_boston_housing (1).csv')

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
x = df.drop('MEDV',axis=1)

# %%
x.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y = df['MEDV']

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
mms = MinMaxScaler()
mms.fit(x)
x = mms.transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=123)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128, input_shape=(13, ), activation='relu', name= 'dense_1'))
model.add(Dense(64, activation= 'relu', name= 'dense_2'))
model.add(Dense(1, activation='linear', name='output'))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 128)               1792
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  output (Dense)              (None, 1)                 65
#
# ...
# Total params: 10113 (39.50 KB)
# Trainable params: 10113 (39.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train, epochs=100, validation_split=0.05, verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 24ms/step - loss: 534.6598 - mae: 21.2076 - val_loss: 580.9831 - val_mae: 21.7076
# Epoch 2/100
# 12/12 [==============================] - 0s 5ms/step - loss: 463.4199 - mae: 19.3485 - val_loss: 487.9621 - val_mae: 19.3376
# Epoch 3/100
# 12/12 [==============================] - 0s 5ms/step - loss: 361.0493 - mae: 16.3332 - val_loss: 360.5158 - val_mae: 15.4705
# Epoch 4/100
# 12/12 [==============================] - 0s 6ms/step - loss: 237.6590 - mae: 12.4374 - val_loss: 228.8460 - val_mae: 10.9578
# Epoch 5/100
# 12/12 [==============================] - 0s 4ms/step - loss: 151.4140 - mae: 9.6078 - val_loss: 157.8882 - val_mae: 9.1621
# Epoch 6/100
# 12/12 [==============================] - 0s 5ms/step - loss: 129.8750 - mae: 8.8411 - val_loss: 139.0378 - val_mae: 8.8302
# Epoch 7/100
# 12/12 [==============================] - 0s 6ms/step - loss: 112.1191 - mae: 8.1137 - val_loss: 129.0135 - val_mae: 8.2828
# Epoch 8/100
# ...

# %%
mse_nn, mae_nn = model.evaluate(x_test,y_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 23.5127 - mae: 3.0180

# %%
print(mse_nn)
print(mae_nn)
# Out:
# 23.512678146362305
# 3.0179831981658936
